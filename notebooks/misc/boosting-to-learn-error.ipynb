# %%
import random
import time
from itertools import product, islice
from collections import defaultdict
from copy import deepcopy
from tqdm.auto import tqdm

import numpy as np
import matplotlib.pyplot as plt

from scipy import optimize

import torch
import torch.nn as nn

# %%
device = 'cuda:0' if torch.cuda.is_available() else 'cpu'
# device = 'cpu'
torch.set_default_dtype(torch.float64)
device
# Out:
# 'cuda:0'

# %%
def get_func(model: nn.Module, loss_fn, x, y):
    def func(*p_tensors):
        assert len(list(model.parameters())) == len(p_tensors)
        assert type(model) is nn.Sequential
        i = 0
        z = x
        for module in model:
            if type(module) is nn.Linear:
                if module.bias is None:
                    z = nn.functional.linear(z, p_tensors[i], None)
                    i += 1
                else:
                    z = nn.functional.linear(z, p_tensors[i], p_tensors[i+1])
                    i += 2
            if type(module) in [nn.Tanh, nn.Sigmoid, nn.ReLU]:
                z = module(z)
        return loss_fn(z, y)
    return func

def hessian_autograd(model, loss_fn, x, y):
    H = torch.autograd.functional.hessian(get_func(model, loss_fn, x, y), tuple(model.parameters()))
    return H

def hvp_autograd(model, v, loss_fn, x, y):
    _, Hv = torch.autograd.functional.hvp(get_func(model, loss_fn, x, y), tuple(model.parameters()), v)
    return Hv

def decompose_hessian(hessian, lengths, shapes):
    H_matrix = torch.zeros(sum(lenghts), sum(lenghts))
    for i, j in product(range(len(shapes)), range(len(shapes))):
        i0, i1 = sum(lenghts[:i+1]) - lenghts[i], sum(lenghts[:i+1])
        j0, j1 = sum(lenghts[:j+1]) - lenghts[j], sum(lenghts[:j+1])
        H_matrix[i0:i1, j0:j1] = hessian[i][j].reshape(lenghts[i], lenghts[j])
    vals, vecs = torch.linalg.eigh(H_matrix)
    vs = []
    for i in range(sum(lenghts)):
        vec = vecs[:, i]
        v = tuple(vec[sum(lenghts[:i]):sum(lenghts[:i+1])].reshape(shapes[i]) for i in range(len(lenghts)))
        vs.append(v)
    return vals, vs

# %%
rmse_loss_fn_torch = lambda x, y: torch.sqrt(torch.mean(torch.pow(x-y, 2)))
qmqe_loss_fn_torch = lambda x, y: torch.pow(torch.mean(torch.pow(x-y, 4)), 1/4)
smse_loss_fn_torch = lambda x, y: torch.pow(torch.mean(torch.pow(x-y, 6)), 1/6)
mse_loss_fn_torch = nn.MSELoss()

def lp_norm(p):
    def loss(x, y):
        return torch.pow(torch.mean(torch.pow(torch.abs(x-y), p)), 1/p)
    return loss

def dl_loss(epsilon):
    def loss(x, y):
        return torch.mean(0.5 * torch.log2(1 + torch.pow((x-y) / epsilon, 2)))
    return loss

# %%
def loss(param_vector, lenghts, shapes, 
             mlp, loss_fn, x, y, device=device):
    l = 0
    for i, param in enumerate(mlp.parameters()):
        param_data = param_vector[l:l+lenghts[i]]
        l += lenghts[i]
        param_data_shaped = param_data.reshape(shapes[i])
        param.data = torch.tensor(param_data_shaped).to(device)
    return loss_fn(mlp(x.to(device)), y).detach().cpu().numpy()

def gradient(param_vector, lenghts, shapes, 
             mlp, loss_fn, x, y, device=device):
    l = 0
    for i, param in enumerate(mlp.parameters()):
        param_data = param_vector[l:l+lenghts[i]]
        l += lenghts[i]
        param_data_shaped = param_data.reshape(shapes[i])
        param.data = torch.tensor(param_data_shaped).to(device)
    loss_fn(mlp(x.to(device)), y).backward()
    grads = []
    for param in mlp.parameters():
        grads.append(param.grad.detach().clone().cpu().numpy().flatten())
        param.grad = None
    mlp.zero_grad()
    return np.concatenate(grads)

# %%
coeffs = (a, b, c, d, e, f) = np.random.uniform(low=-1.5, high=1.5, size=(6,))
x_i = np.random.uniform(low=-1, high=1, size=(50000, 1))
y_i = a + b*np.power(x_i, 1) + c*np.power(x_i, 2) + d*np.power(x_i, 3) + e*np.power(x_i, 4) + f*np.power(x_i, 5)

x_i = torch.from_numpy(x_i).to(device)
y_i = torch.from_numpy(y_i).to(device)

# %%
plt.scatter(x_i.cpu(), y_i.cpu())

# %%
width = 20
mlp = nn.Sequential(
    nn.Linear(1, width),
    nn.Tanh(),
    nn.Linear(width, width),
    nn.Tanh(),
    nn.Linear(width, 1)
).to(device)

params = []
shapes = []
lenghts = []
for param in mlp.parameters():
    param_np = param.data.detach().clone().cpu().numpy()
    shapes.append(param_np.shape)
    param_np_flat = param_np.flatten()
    lenghts.append(len(param_np_flat))
    params.append(param_np_flat)

param_vector = np.concatenate(params)

# %%
result = optimize.minimize(loss,
                       param_vector, 
                       args=(lenghts, shapes, mlp, mse_loss_fn_torch, x_i, y_i, device),
                       jac=gradient,
                       method='BFGS',
                       options={
                           'disp': True,
                           'gtol': 1e-40,
                           'maxiter': 25000,
#                                'finite_diff_rel_step': 1e-15
                       },
                    )

l = 0
for j, param in enumerate(mlp.parameters()):
    param_data = result.x[l:l+lenghts[j]]
    l += lenghts[j]
    param_data_shaped = param_data.reshape(shapes[j])
    param.data = torch.tensor(param_data_shaped).to(device)

l = mse_loss_fn_torch(mlp(x_i), y_i).item()
print(l)
mlp.zero_grad()
# Out:
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 6665
#          Function evaluations: 7737
#          Gradient evaluations: 7725
# 1.0930673575791284e-12

# %%
with torch.no_grad():
    plt.scatter(x_i.cpu(), y_i.cpu() - mlp(x_i).cpu())

# %%
with torch.no_grad():
    c = 1 / torch.mean(torch.abs(y_i - mlp(x_i))).item()
    yd_i = c * (y_i - mlp(x_i))

# %%
plt.scatter(x_i.cpu(), yd_i.cpu())

# %%
width = 20
mlp2 = nn.Sequential(
    nn.Linear(1, width),
    nn.Tanh(),
    nn.Linear(width, width),
    nn.Tanh(),
    nn.Linear(width, 1)
).to(device)

params = []
shapes = []
lenghts = []
for param in mlp2.parameters():
    param_np = param.data.detach().clone().cpu().numpy()
    shapes.append(param_np.shape)
    param_np_flat = param_np.flatten()
    lenghts.append(len(param_np_flat))
    params.append(param_np_flat)

param_vector = np.concatenate(params)

# %%
result = optimize.minimize(loss,
                       param_vector, 
                       args=(lenghts, shapes, mlp2, mse_loss_fn_torch, x_i, yd_i, device),
                       jac=gradient,
                       method='BFGS',
                       options={
                           'disp': True,
                           'gtol': 1e-40,
                           'maxiter': 25000,
#                                'finite_diff_rel_step': 1e-15
                       },
                    )

l = 0
for j, param in enumerate(mlp2.parameters()):
    param_data = result.x[l:l+lenghts[j]]
    l += lenghts[j]
    param_data_shaped = param_data.reshape(shapes[j])
    param.data = torch.tensor(param_data_shaped).to(device)

l = mse_loss_fn_torch(mlp2(x_i), yd_i).item()
print(l)
mlp2.zero_grad()
# Out:
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 24856
#          Function evaluations: 26156
#          Gradient evaluations: 26144
# 3.3707178435879613e-09

# %%
with torch.no_grad():
#     plt.scatter(x_i.cpu(), yd_i.cpu())
    plt.scatter(x_i.cpu(), mlp2(x_i).cpu())

# %%
with torch.no_grad():
    print(mse_loss_fn_torch(mlp(x_i) + (1/c)*mlp2(x_i), y_i).item())
# Out:
# 2.8857238318518905e-21

# %%
with torch.no_grad():
    c2 = 1 / torch.mean(torch.abs(y_i - (mlp(x_i) + (1/c)*mlp2(x_i)))).item()
    yd2_i = c2 * (y_i - (mlp(x_i) + (1/c)*mlp2(x_i)))

# %%
with torch.no_grad():
    plt.scatter(x_i.cpu(), (y_i - (mlp(x_i) + (1/c)*mlp2(x_i))).cpu(), s=7)

# %%
width = 20
mlp3 = nn.Sequential(
    nn.Linear(1, width),
    nn.Tanh(),
    nn.Linear(width, width),
    nn.Tanh(),
    nn.Linear(width, 1)
).to(device)

params = []
shapes = []
lenghts = []
for param in mlp3.parameters():
    param_np = param.data.detach().clone().cpu().numpy()
    shapes.append(param_np.shape)
    param_np_flat = param_np.flatten()
    lenghts.append(len(param_np_flat))
    params.append(param_np_flat)

param_vector = np.concatenate(params)

# %%
result = optimize.minimize(loss,
                       param_vector, 
                       args=(lenghts, shapes, mlp3, mse_loss_fn_torch, x_i, yd2_i, device),
                       jac=gradient,
                       method='BFGS',
                       options={
                           'disp': True,
                           'gtol': 1e-40,
                           'maxiter': 25000,
#                                'finite_diff_rel_step': 1e-15
                       },
                    )

l = 0
for j, param in enumerate(mlp3.parameters()):
    param_data = result.x[l:l+lenghts[j]]
    l += lenghts[j]
    param_data_shaped = param_data.reshape(shapes[j])
    param.data = torch.tensor(param_data_shaped).to(device)

l = mse_loss_fn_torch(mlp3(x_i), yd2_i).item()
print(l)
mlp3.zero_grad()
# Out:
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 1.790141
#          Iterations: 24061
#          Function evaluations: 25196
#          Gradient evaluations: 25184
# 1.790141477914346

# %%
with torch.no_grad():
    plt.scatter(x_i.cpu(), yd2_i.cpu())
    plt.scatter(x_i.cpu(), mlp3(x_i).cpu())

# %%
with torch.no_grad():
    print(mse_loss_fn_torch(mlp(x_i) + (1/c)*mlp2(x_i) + (1/c2)*mlp3(x_i), y_i).item())
# Out:
# 2.1022000653311976e-21

# %% [markdown]
# ### Let's compare a width 20 network performance to a 10 + 10 (boosted) ensemble performance

# %%
coeffs = (a, b, c, d, e, f) = np.random.uniform(low=-1.5, high=1.5, size=(6,))
x_i = np.random.uniform(low=-1, high=1, size=(50000, 1))
y_i = a + b*np.power(x_i, 1) + c*np.power(x_i, 2) + d*np.power(x_i, 3) + e*np.power(x_i, 4) + f*np.power(x_i, 5)

x_i = torch.from_numpy(x_i).to(device)
y_i = torch.from_numpy(y_i).to(device)

# %%
plt.scatter(x_i.cpu(), y_i.cpu())

# %%
# width-20 network

width = 20
mlp = nn.Sequential(
    nn.Linear(1, width),
    nn.Tanh(),
    nn.Linear(width, width),
    nn.Tanh(),
    nn.Linear(width, 1)
).to(device)

params = []
shapes = []
lenghts = []
for param in mlp.parameters():
    param_np = param.data.detach().clone().cpu().numpy()
    shapes.append(param_np.shape)
    param_np_flat = param_np.flatten()
    lenghts.append(len(param_np_flat))
    params.append(param_np_flat)

param_vector = np.concatenate(params)

result = optimize.minimize(loss,
                       param_vector, 
                       args=(lenghts, shapes, mlp, mse_loss_fn_torch, x_i, y_i, device),
                       jac=gradient,
                       method='BFGS',
                       options={
                           'disp': True,
                           'gtol': 1e-40,
                           'maxiter': 25000,
#                                'finite_diff_rel_step': 1e-15
                       },
                    )

l = 0
for j, param in enumerate(mlp.parameters()):
    param_data = result.x[l:l+lenghts[j]]
    l += lenghts[j]
    param_data_shaped = param_data.reshape(shapes[j])
    param.data = torch.tensor(param_data_shaped).to(device)

l = mse_loss_fn_torch(mlp(x_i), y_i).item()
print(l)
mlp.zero_grad()
# Out:
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 9670
#          Function evaluations: 10953
#          Gradient evaluations: 10943
# 5.835053349765892e-13

# %%
# 10 + 10

width = 10
f1 = nn.Sequential(
    nn.Linear(1, width),
    nn.Tanh(),
    nn.Linear(width, width),
    nn.Tanh(),
    nn.Linear(width, 1)
).to(device)

params1 = []
shapes1 = []
lengths1 = []
for param in f1.parameters():
    param_np = param.data.detach().clone().cpu().numpy()
    shapes1.append(param_np.shape)
    param_np_flat = param_np.flatten()
    lengths1.append(len(param_np_flat))
    params1.append(param_np_flat)

param_vector1 = np.concatenate(params1)

result = optimize.minimize(loss,
                       param_vector1, 
                       args=(lengths1, shapes1, f1, mse_loss_fn_torch, x_i, y_i, device),
                       jac=gradient,
                       method='BFGS',
                       options={
                           'disp': True,
                           'gtol': 1e-40,
                           'maxiter': 25000,
#                                'finite_diff_rel_step': 1e-15
                       },
                    )

l = 0
for j, param in enumerate(f1.parameters()):
    param_data = result.x[l:l+lengths1[j]]
    l += lengths1[j]
    param_data_shaped = param_data.reshape(shapes1[j])
    param.data = torch.tensor(param_data_shaped).to(device)

l = mse_loss_fn_torch(f1(x_i), y_i).item()
print(l)
f1.zero_grad()


with torch.no_grad():
    c1 = 1 / torch.mean(torch.abs(y_i - f1(x_i))).item()
    yd1_i = c1 * (y_i - f1(x_i))


width = 10
f2 = nn.Sequential(
    nn.Linear(1, width),
    nn.Tanh(),
    nn.Linear(width, width),
    nn.Tanh(),
    nn.Linear(width, 1)
).to(device)

params2 = []
shapes2 = []
lengths2 = []
for param in f2.parameters():
    param_np = param.data.detach().clone().cpu().numpy()
    shapes2.append(param_np.shape)
    param_np_flat = param_np.flatten()
    lengths2.append(len(param_np_flat))
    params2.append(param_np_flat)

param_vector2 = np.concatenate(params1)



result = optimize.minimize(loss,
                       param_vector2, 
                       args=(lengths2, shapes2, f2, mse_loss_fn_torch, x_i, yd1_i, device),
                       jac=gradient,
                       method='BFGS',
                       options={
                           'disp': True,
                           'gtol': 1e-40,
                           'maxiter': 25000,
#                                'finite_diff_rel_step': 1e-15
                       },
                    )

l = 0
for j, param in enumerate(f2.parameters()):
    param_data = result.x[l:l+lengths2[j]]
    l += lengths2[j]
    param_data_shaped = param_data.reshape(shapes2[j])
    param.data = torch.tensor(param_data_shaped).to(device)

l = mse_loss_fn_torch(f2(x_i), yd1_i).item()
print(l)
f2.zero_grad()


with torch.no_grad():
    print("Boosted loss: {}".format(mse_loss_fn_torch(f1(x_i) + (1/c1)*f2(x_i), y_i).item()))
# Out:
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 5413
#          Function evaluations: 6212
#          Gradient evaluations: 6201
# 1.5876431675881177e-12
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000001
#          Iterations: 6463
#          Function evaluations: 6908
#          Gradient evaluations: 6896
# 1.1288874097005012e-06
# Boosted loss: 1.2372960325165759e-18

# %% [markdown]
# ## Let's look at scaling laws and consistency between runs

# %%
widths = [4, 6, 8, 10, 12, 16, 18, 20, 22, 24]
repeats = 10

results = defaultdict(list)

for width in tqdm(widths):
    for _ in tqdm(range(repeats), leave=False):

        mlp = nn.Sequential(
            nn.Linear(1, width),
            nn.Tanh(),
            nn.Linear(width, width),
            nn.Tanh(),
            nn.Linear(width, 1)
        ).to(device)

        params = []
        shapes = []
        lenghts = []
        for param in mlp.parameters():
            param_np = param.data.detach().clone().cpu().numpy()
            shapes.append(param_np.shape)
            param_np_flat = param_np.flatten()
            lenghts.append(len(param_np_flat))
            params.append(param_np_flat)

        param_vector = np.concatenate(params)

        result = optimize.minimize(loss,
                               param_vector, 
                               args=(lenghts, shapes, mlp, mse_loss_fn_torch, x_i, y_i, device),
                               jac=gradient,
                               method='BFGS',
                               options={
                                   'disp': True,
                                   'gtol': 1e-40,
                                   'maxiter': 25000,
        #                                'finite_diff_rel_step': 1e-15
                               },
                            )

        l = 0
        for j, param in enumerate(mlp.parameters()):
            param_data = result.x[l:l+lenghts[j]]
            l += lenghts[j]
            param_data_shaped = param_data.reshape(shapes[j])
            param.data = torch.tensor(param_data_shaped).to(device)

        results[width].append(mse_loss_fn_torch(mlp(x_i), y_i).item())
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 5138
#          Function evaluations: 5775
#          Gradient evaluations: 5763
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 14273
#          Function evaluations: 16170
#          Gradient evaluations: 16158
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 3015
#          Function evaluations: 3492
#          Gradient evaluations: 3480
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 2234
#          Function evaluations: 2593
#          Gradient evaluations: 2581
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 6743
#          Function evaluations: 7624
#          Gradient evaluations: 7614
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 1750
#          Function evaluations: 2037
#          Gradient evaluations: 2025
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 10954
#          Function evaluations: 12463
#          Gradient evaluations: 12451
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 10360
#          Function evaluations: 11825
#          Gradient evaluations: 11815
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 7065
#          Function evaluations: 8058
#          Gradient evaluations: 8046
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 5756
#          Function evaluations: 6599
#          Gradient evaluations: 6587
#   0%|          | 0/10 [00:00<?, ?it/s]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 7090
#          Function evaluations: 8034
#          Gradient evaluations: 8022
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 4574
#          Function evaluations: 5215
#          Gradient evaluations: 5203
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 7809
#          Function evaluations: 8767
#          Gradient evaluations: 8757
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 10876
#          Function evaluations: 12364
#          Gradient evaluations: 12352
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 9851
#          Function evaluations: 11202
#          Gradient evaluations: 11191
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 16510
#          Function evaluations: 18767
#          Gradient evaluations: 18755
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 4782
#          Function evaluations: 5422
#          Gradient evaluations: 5410
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 4260
#          Function evaluations: 4804
#          Gradient evaluations: 4793
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 6648
#          Function evaluations: 7631
#          Gradient evaluations: 7619
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 8450
#          Function evaluations: 9645
#          Gradient evaluations: 9633
#   0%|          | 0/10 [00:00<?, ?it/s]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 9348
#          Function evaluations: 10488
#          Gradient evaluations: 10478
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 4651
#          Function evaluations: 5262
#          Gradient evaluations: 5251
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 6652
#          Function evaluations: 7638
#          Gradient evaluations: 7626
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 7893
#          Function evaluations: 9041
#          Gradient evaluations: 9029
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 7751
#          Function evaluations: 8715
#          Gradient evaluations: 8707
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 16003
#          Function evaluations: 17968
#          Gradient evaluations: 17956
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 12417
#          Function evaluations: 14084
#          Gradient evaluations: 14073
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 6741
#          Function evaluations: 7741
#          Gradient evaluations: 7731
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 7746
#          Function evaluations: 8910
#          Gradient evaluations: 8900
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 5443
#          Function evaluations: 6194
#          Gradient evaluations: 6182
#   0%|          | 0/10 [00:00<?, ?it/s]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 10310
#          Function evaluations: 11728
#          Gradient evaluations: 11716
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 4453
#          Function evaluations: 5059
#          Gradient evaluations: 5049
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 6152
#          Function evaluations: 6970
#          Gradient evaluations: 6961
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 5637
#          Function evaluations: 6452
#          Gradient evaluations: 6442
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 8747
#          Function evaluations: 9946
#          Gradient evaluations: 9934
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 9992
#          Function evaluations: 11433
#          Gradient evaluations: 11421
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 8042
#          Function evaluations: 9210
#          Gradient evaluations: 9199
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 7386
#          Function evaluations: 8453
#          Gradient evaluations: 8443
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 11073
#          Function evaluations: 12511
#          Gradient evaluations: 12499
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 5621
#          Function evaluations: 6344
#          Gradient evaluations: 6332
#   0%|          | 0/10 [00:00<?, ?it/s]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 8258
#          Function evaluations: 9325
#          Gradient evaluations: 9313
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 12721
#          Function evaluations: 14499
#          Gradient evaluations: 14487
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 9693
#          Function evaluations: 10981
#          Gradient evaluations: 10971
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 4539
#          Function evaluations: 5162
#          Gradient evaluations: 5150
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 13978
#          Function evaluations: 15815
#          Gradient evaluations: 15803
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 8581
#          Function evaluations: 9804
#          Gradient evaluations: 9796
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 7519
#          Function evaluations: 8518
#          Gradient evaluations: 8508
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 14943
#          Function evaluations: 17034
#          Gradient evaluations: 17022
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 14694
#          Function evaluations: 16621
#          Gradient evaluations: 16609
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 6518
#          Function evaluations: 7367
#          Gradient evaluations: 7356
#   0%|          | 0/10 [00:00<?, ?it/s]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 8370
#          Function evaluations: 9651
#          Gradient evaluations: 9640
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 10093
#          Function evaluations: 11540
#          Gradient evaluations: 11532
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 4185
#          Function evaluations: 4734
#          Gradient evaluations: 4722
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 9805
#          Function evaluations: 11095
#          Gradient evaluations: 11083
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 7281
#          Function evaluations: 8261
#          Gradient evaluations: 8249
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 5519
#          Function evaluations: 6220
#          Gradient evaluations: 6209
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 4485
#          Function evaluations: 5076
#          Gradient evaluations: 5066
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 12172
#          Function evaluations: 13831
#          Gradient evaluations: 13819
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 4980
#          Function evaluations: 5724
#          Gradient evaluations: 5713
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 7520
#          Function evaluations: 8613
#          Gradient evaluations: 8602
#   0%|          | 0/10 [00:00<?, ?it/s]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 7287
#          Function evaluations: 8306
#          Gradient evaluations: 8296
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 7835
#          Function evaluations: 9042
#          Gradient evaluations: 9030
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 6452
#          Function evaluations: 7260
#          Gradient evaluations: 7248
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 6850
#          Function evaluations: 7760
#          Gradient evaluations: 7752
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 8672
#          Function evaluations: 9825
#          Gradient evaluations: 9813
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 14364
#          Function evaluations: 16424
#          Gradient evaluations: 16412
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 3007
#          Function evaluations: 3359
#          Gradient evaluations: 3347
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 6473
#          Function evaluations: 7404
#          Gradient evaluations: 7393
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 8251
#          Function evaluations: 9262
#          Gradient evaluations: 9256
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 7241
#          Function evaluations: 8185
#          Gradient evaluations: 8173
#   0%|          | 0/10 [00:00<?, ?it/s]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 6819
#          Function evaluations: 7750
#          Gradient evaluations: 7738
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 16201
#          Function evaluations: 18617
#          Gradient evaluations: 18605
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 7941
#          Function evaluations: 9186
#          Gradient evaluations: 9174
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 3635
#          Function evaluations: 4170
#          Gradient evaluations: 4158
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 4203
#          Function evaluations: 4732
#          Gradient evaluations: 4720
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 10227
#          Function evaluations: 11684
#          Gradient evaluations: 11672
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 3586
#          Function evaluations: 4062
#          Gradient evaluations: 4050
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 4055
#          Function evaluations: 4557
#          Gradient evaluations: 4545
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 6186
#          Function evaluations: 7007
#          Gradient evaluations: 6996
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 3617
#          Function evaluations: 4052
#          Gradient evaluations: 4040
#   0%|          | 0/10 [00:00<?, ?it/s]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 12826
#          Function evaluations: 14681
#          Gradient evaluations: 14674
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 5070
#          Function evaluations: 5733
#          Gradient evaluations: 5721
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 11346
#          Function evaluations: 12915
#          Gradient evaluations: 12903
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 8350
#          Function evaluations: 9552
#          Gradient evaluations: 9540
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 9805
#          Function evaluations: 11149
#          Gradient evaluations: 11138
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 5479
#          Function evaluations: 6267
#          Gradient evaluations: 6256
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 6238
#          Function evaluations: 7189
#          Gradient evaluations: 7178
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 9224
#          Function evaluations: 10527
#          Gradient evaluations: 10515
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 8876
#          Function evaluations: 10057
#          Gradient evaluations: 10045
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 8140
#          Function evaluations: 9281
#          Gradient evaluations: 9269
#   0%|          | 0/10 [00:00<?, ?it/s]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 8887
#          Function evaluations: 10055
#          Gradient evaluations: 10043
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 9515
#          Function evaluations: 10812
#          Gradient evaluations: 10800
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 19857
#          Function evaluations: 22741
#          Gradient evaluations: 22729
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 6851
#          Function evaluations: 7853
#          Gradient evaluations: 7842
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 5581
#          Function evaluations: 6336
#          Gradient evaluations: 6324
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 15519
#          Function evaluations: 17813
#          Gradient evaluations: 17801
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 6318
#          Function evaluations: 7177
#          Gradient evaluations: 7165
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 4450
#          Function evaluations: 4951
#          Gradient evaluations: 4943
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 4588
#          Function evaluations: 5183
#          Gradient evaluations: 5173
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 5773
#          Function evaluations: 6593
#          Gradient evaluations: 6581

# %%
for width in widths:
    plt.scatter([width]*repeats, results[width], color='C0')
plt.yscale('log')
plt.ylabel("MSE loss")
# plt.xscale('log')
plt.xlabel("width")
plt.title("Pure BFGS training (unboosted)")
# Out:
# Text(0.5, 1.0, 'Pure BFGS training (unboosted)')

# %%
for width in widths:
    n_params = (1 * width + width) + (width * width + width) + (width * 1 + 1)
    plt.scatter([n_params]*repeats, results[width], color='C0')
plt.yscale('log')
plt.ylabel("MSE loss")
plt.xscale('log')
plt.xlabel("parameters")
plt.title("Pure BFGS training")
# Out:
# Text(0.5, 1.0, 'Pure BFGS training')

# %% [markdown]
# ### Now for boosted version

# %%
widths = [4, 6, 8, 10, 12, 16, 18, 20, 22, 24]
repeats = 10

results_boosted = defaultdict(list)

for width in tqdm(widths):
    for _ in tqdm(range(repeats), leave=False):

        f1 = nn.Sequential(
            nn.Linear(1, int(width/2)),
            nn.Tanh(),
            nn.Linear(int(width/2), int(width/2)),
            nn.Tanh(),
            nn.Linear(int(width/2), 1)
        ).to(device)

        params1 = []
        shapes1 = []
        lengths1 = []
        for param in f1.parameters():
            param_np = param.data.detach().clone().cpu().numpy()
            shapes1.append(param_np.shape)
            param_np_flat = param_np.flatten()
            lengths1.append(len(param_np_flat))
            params1.append(param_np_flat)

        param_vector1 = np.concatenate(params1)

        result = optimize.minimize(loss,
                               param_vector1, 
                               args=(lengths1, shapes1, f1, mse_loss_fn_torch, x_i, y_i, device),
                               jac=gradient,
                               method='BFGS',
                               options={
                                   'disp': True,
                                   'gtol': 1e-40,
                                   'maxiter': 25000,
        #                                'finite_diff_rel_step': 1e-15
                               },
                            )

        l = 0
        for j, param in enumerate(f1.parameters()):
            param_data = result.x[l:l+lengths1[j]]
            l += lengths1[j]
            param_data_shaped = param_data.reshape(shapes1[j])
            param.data = torch.tensor(param_data_shaped).to(device)

#         l = mse_loss_fn_torch(f1(x_i), y_i).item()
#         print(l)
#         f1.zero_grad()


        with torch.no_grad():
            c1 = 1 / torch.mean(torch.abs(y_i - f1(x_i))).item()
            yd1_i = c1 * (y_i - f1(x_i))


        f2 = nn.Sequential(
            nn.Linear(1, int(width/2)),
            nn.Tanh(),
            nn.Linear(int(width/2), int(width/2)),
            nn.Tanh(),
            nn.Linear(int(width/2), 1)
        ).to(device)

        params2 = []
        shapes2 = []
        lengths2 = []
        for param in f2.parameters():
            param_np = param.data.detach().clone().cpu().numpy()
            shapes2.append(param_np.shape)
            param_np_flat = param_np.flatten()
            lengths2.append(len(param_np_flat))
            params2.append(param_np_flat)

        param_vector2 = np.concatenate(params1)


        result = optimize.minimize(loss,
                               param_vector2, 
                               args=(lengths2, shapes2, f2, mse_loss_fn_torch, x_i, yd1_i, device),
                               jac=gradient,
                               method='BFGS',
                               options={
                                   'disp': True,
                                   'gtol': 1e-40,
                                   'maxiter': 25000,
        #                                'finite_diff_rel_step': 1e-15
                               },
                            )

        l = 0
        for j, param in enumerate(f2.parameters()):
            param_data = result.x[l:l+lengths2[j]]
            l += lengths2[j]
            param_data_shaped = param_data.reshape(shapes2[j])
            param.data = torch.tensor(param_data_shaped).to(device)

#         l = mse_loss_fn_torch(f2(x_i), yd1_i).item()
#         print(l)
#         f2.zero_grad()

        with torch.no_grad():
            results_boosted[width].append(mse_loss_fn_torch(f1(x_i) + (1/c1)*f2(x_i), y_i).item())
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000001
#          Iterations: 4093
#          Function evaluations: 4800
#          Gradient evaluations: 4788
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 1.101032
#          Iterations: 1193
#          Function evaluations: 1465
#          Gradient evaluations: 1453
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.008906
#          Iterations: 451
#          Function evaluations: 592
#          Gradient evaluations: 580
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.165407
#          Iterations: 528
#          Function evaluations: 612
#          Gradient evaluations: 600
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000001
#          Iterations: 2124
#          Function evaluations: 2433
#          Gradient evaluations: 2421
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.448780
#          Iterations: 2347
#          Function evaluations: 2767
#          Gradient evaluations: 2755
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000336
#          Iterations: 994
#          Function evaluations: 1212
#          Gradient evaluations: 1200
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.299264
#          Iterations: 836
#          Function evaluations: 988
#          Gradient evaluations: 976
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000322
#          Iterations: 375
#          Function evaluations: 463
#          Gradient evaluations: 451
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000073
#          Iterations: 3588
#          Function evaluations: 4325
#          Gradient evaluations: 4313
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.137414
#          Iterations: 2463
#          Function evaluations: 2863
#          Gradient evaluations: 2851
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.047333
#          Iterations: 1224
#          Function evaluations: 1499
#          Gradient evaluations: 1487
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.024536
#          Iterations: 1107
#          Function evaluations: 1301
#          Gradient evaluations: 1289
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000024
#          Iterations: 1103
#          Function evaluations: 1294
#          Gradient evaluations: 1282
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.647855
#          Iterations: 785
#          Function evaluations: 955
#          Gradient evaluations: 943
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000013
#          Iterations: 5342
#          Function evaluations: 6329
#          Gradient evaluations: 6317
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.871512
#          Iterations: 560
#          Function evaluations: 686
#          Gradient evaluations: 674
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000001
#          Iterations: 1825
#          Function evaluations: 2127
#          Gradient evaluations: 2115
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 1.314268
#          Iterations: 1122
#          Function evaluations: 1317
#          Gradient evaluations: 1305
#   0%|          | 0/10 [00:00<?, ?it/s]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 8272
#          Function evaluations: 9553
#          Gradient evaluations: 9541
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.925330
#          Iterations: 603
#          Function evaluations: 684
#          Gradient evaluations: 672
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 18690
#          Function evaluations: 21289
#          Gradient evaluations: 21278
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.485651
#          Iterations: 879
#          Function evaluations: 1040
#          Gradient evaluations: 1028
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000040
#          Iterations: 2527
#          Function evaluations: 2951
#          Gradient evaluations: 2939
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.093999
#          Iterations: 2508
#          Function evaluations: 2763
#          Gradient evaluations: 2751
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 8563
#          Function evaluations: 9837
#          Gradient evaluations: 9825
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.451550
#          Iterations: 1069
#          Function evaluations: 1243
#          Gradient evaluations: 1231
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 9341
#          Function evaluations: 10808
#          Gradient evaluations: 10796
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.065383
#          Iterations: 16751
#          Function evaluations: 18324
#          Gradient evaluations: 18312
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 12075
#          Function evaluations: 13807
#          Gradient evaluations: 13795
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.008341
#          Iterations: 2801
#          Function evaluations: 3137
#          Gradient evaluations: 3125
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 2226
#          Function evaluations: 2554
#          Gradient evaluations: 2542
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.362541
#          Iterations: 3288
#          Function evaluations: 3635
#          Gradient evaluations: 3623
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 3366
#          Function evaluations: 3933
#          Gradient evaluations: 3921
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000009
#          Iterations: 2293
#          Function evaluations: 2574
#          Gradient evaluations: 2562
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 6678
#          Function evaluations: 7684
#          Gradient evaluations: 7672
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.197709
#          Iterations: 1637
#          Function evaluations: 1798
#          Gradient evaluations: 1786
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 7916
#          Function evaluations: 9037
#          Gradient evaluations: 9025
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.335215
#          Iterations: 3807
#          Function evaluations: 4227
#          Gradient evaluations: 4215
#   0%|          | 0/10 [00:00<?, ?it/s]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 7547
#          Function evaluations: 8545
#          Gradient evaluations: 8533
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.071011
#          Iterations: 3774
#          Function evaluations: 4156
#          Gradient evaluations: 4144
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 7359
#          Function evaluations: 8387
#          Gradient evaluations: 8380
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.001540
#          Iterations: 3460
#          Function evaluations: 3825
#          Gradient evaluations: 3813
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 12057
#          Function evaluations: 13826
#          Gradient evaluations: 13815
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.211128
#          Iterations: 3112
#          Function evaluations: 3446
#          Gradient evaluations: 3434
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 18568
#          Function evaluations: 21330
#          Gradient evaluations: 21318
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.298651
#          Iterations: 3784
#          Function evaluations: 4141
#          Gradient evaluations: 4129
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 8701
#          Function evaluations: 9876
#          Gradient evaluations: 9871
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 1.347222
#          Iterations: 183
#          Function evaluations: 202
#          Gradient evaluations: 202
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 19048
#          Function evaluations: 22115
#          Gradient evaluations: 22103
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.459070
#          Iterations: 2091
#          Function evaluations: 2421
#          Gradient evaluations: 2409
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 4275
#          Function evaluations: 4820
#          Gradient evaluations: 4809
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 1.623328
#          Iterations: 83
#          Function evaluations: 89
#          Gradient evaluations: 89
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 5398
#          Function evaluations: 6098
#          Gradient evaluations: 6087
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.177872
#          Iterations: 2131
#          Function evaluations: 2377
#          Gradient evaluations: 2365
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 10953
#          Function evaluations: 12595
#          Gradient evaluations: 12583
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.694592
#          Iterations: 2947
#          Function evaluations: 3278
#          Gradient evaluations: 3266
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 4794
#          Function evaluations: 5450
#          Gradient evaluations: 5438
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.510110
#          Iterations: 1302
#          Function evaluations: 1456
#          Gradient evaluations: 1444
#   0%|          | 0/10 [00:00<?, ?it/s]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 3614
#          Function evaluations: 4150
#          Gradient evaluations: 4138
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.036797
#          Iterations: 2536
#          Function evaluations: 2784
#          Gradient evaluations: 2772
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 9102
#          Function evaluations: 10467
#          Gradient evaluations: 10455
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.785425
#          Iterations: 2559
#          Function evaluations: 2853
#          Gradient evaluations: 2841
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 10303
#          Function evaluations: 11816
#          Gradient evaluations: 11804
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.256869
#          Iterations: 4999
#          Function evaluations: 5415
#          Gradient evaluations: 5403
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 4314
#          Function evaluations: 4870
#          Gradient evaluations: 4858
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000181
#          Iterations: 5789
#          Function evaluations: 6192
#          Gradient evaluations: 6180
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 5278
#          Function evaluations: 5987
#          Gradient evaluations: 5975
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.446238
#          Iterations: 4201
#          Function evaluations: 4635
#          Gradient evaluations: 4623
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 7342
#          Function evaluations: 8198
#          Gradient evaluations: 8187
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.736648
#          Iterations: 3478
#          Function evaluations: 3841
#          Gradient evaluations: 3829
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 3684
#          Function evaluations: 4112
#          Gradient evaluations: 4100
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000012
#          Iterations: 5631
#          Function evaluations: 6070
#          Gradient evaluations: 6058
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 5617
#          Function evaluations: 6406
#          Gradient evaluations: 6394
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000123
#          Iterations: 9887
#          Function evaluations: 11161
#          Gradient evaluations: 11150
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 12338
#          Function evaluations: 14178
#          Gradient evaluations: 14166
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.001351
#          Iterations: 6148
#          Function evaluations: 6670
#          Gradient evaluations: 6658
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 8033
#          Function evaluations: 9192
#          Gradient evaluations: 9180
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000159
#          Iterations: 7727
#          Function evaluations: 8449
#          Gradient evaluations: 8437
#   0%|          | 0/10 [00:00<?, ?it/s]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 8089
#          Function evaluations: 9189
#          Gradient evaluations: 9178
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000560
#          Iterations: 8052
#          Function evaluations: 8813
#          Gradient evaluations: 8801
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 5381
#          Function evaluations: 6120
#          Gradient evaluations: 6108
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000009
#          Iterations: 7004
#          Function evaluations: 7535
#          Gradient evaluations: 7523
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 5969
#          Function evaluations: 6745
#          Gradient evaluations: 6734
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 1.565029
#          Iterations: 82
#          Function evaluations: 91
#          Gradient evaluations: 91
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 7153
#          Function evaluations: 8188
#          Gradient evaluations: 8177
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000052
#          Iterations: 13902
#          Function evaluations: 14731
#          Gradient evaluations: 14719
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 4857
#          Function evaluations: 5488
#          Gradient evaluations: 5477
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 11875
#          Function evaluations: 12844
#          Gradient evaluations: 12832
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 9976
#          Function evaluations: 11260
#          Gradient evaluations: 11248
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000995
#          Iterations: 5002
#          Function evaluations: 5423
#          Gradient evaluations: 5411
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 6783
#          Function evaluations: 7774
#          Gradient evaluations: 7762
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000138
#          Iterations: 5827
#          Function evaluations: 6342
#          Gradient evaluations: 6330
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 6525
#          Function evaluations: 7298
#          Gradient evaluations: 7286
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.008838
#          Iterations: 5989
#          Function evaluations: 6414
#          Gradient evaluations: 6402
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 16205
#          Function evaluations: 18371
#          Gradient evaluations: 18361
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 1.535141
#          Iterations: 61
#          Function evaluations: 65
#          Gradient evaluations: 65
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 7792
#          Function evaluations: 8756
#          Gradient evaluations: 8745
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.509561
#          Iterations: 6812
#          Function evaluations: 7303
#          Gradient evaluations: 7291
#   0%|          | 0/10 [00:00<?, ?it/s]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 13616
#          Function evaluations: 15323
#          Gradient evaluations: 15312
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.069132
#          Iterations: 8817
#          Function evaluations: 9463
#          Gradient evaluations: 9451
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 8666
#          Function evaluations: 9865
#          Gradient evaluations: 9856
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000001
#          Iterations: 11577
#          Function evaluations: 12324
#          Gradient evaluations: 12312
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 8276
#          Function evaluations: 9343
#          Gradient evaluations: 9332
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.169954
#          Iterations: 10823
#          Function evaluations: 11511
#          Gradient evaluations: 11499
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 9392
#          Function evaluations: 10844
#          Gradient evaluations: 10832
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.004388
#          Iterations: 3252
#          Function evaluations: 3539
#          Gradient evaluations: 3527
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 9777
#          Function evaluations: 11195
#          Gradient evaluations: 11184
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000050
#          Iterations: 16307
#          Function evaluations: 17671
#          Gradient evaluations: 17659
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 6853
#          Function evaluations: 7711
#          Gradient evaluations: 7699
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000015
#          Iterations: 8146
#          Function evaluations: 8782
#          Gradient evaluations: 8770
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 4097
#          Function evaluations: 4663
#          Gradient evaluations: 4651
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000002
#          Iterations: 7860
#          Function evaluations: 8506
#          Gradient evaluations: 8494
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 8581
#          Function evaluations: 9705
#          Gradient evaluations: 9693
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000007
#          Iterations: 7034
#          Function evaluations: 7598
#          Gradient evaluations: 7586
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 9017
#          Function evaluations: 10255
#          Gradient evaluations: 10243
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000001
#          Iterations: 10322
#          Function evaluations: 11211
#          Gradient evaluations: 11199
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 5167
#          Function evaluations: 5863
#          Gradient evaluations: 5851
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 14019
#          Function evaluations: 15252
#          Gradient evaluations: 15240
#   0%|          | 0/10 [00:00<?, ?it/s]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 8173
#          Function evaluations: 9290
#          Gradient evaluations: 9278
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.220179
#          Iterations: 13653
#          Function evaluations: 14586
#          Gradient evaluations: 14574
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 7966
#          Function evaluations: 9047
#          Gradient evaluations: 9035
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.797702
#          Iterations: 25000
#          Function evaluations: 26391
#          Gradient evaluations: 26391
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 4392
#          Function evaluations: 4921
#          Gradient evaluations: 4910
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000001
#          Iterations: 5672
#          Function evaluations: 6090
#          Gradient evaluations: 6078
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 7054
#          Function evaluations: 7981
#          Gradient evaluations: 7969
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 1.688276
#          Iterations: 225
#          Function evaluations: 244
#          Gradient evaluations: 244
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 11503
#          Function evaluations: 13029
#          Gradient evaluations: 13019
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 1.446684
#          Iterations: 83
#          Function evaluations: 88
#          Gradient evaluations: 88
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 6751
#          Function evaluations: 7763
#          Gradient evaluations: 7752
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000001
#          Iterations: 9664
#          Function evaluations: 10257
#          Gradient evaluations: 10245
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 6998
#          Function evaluations: 7897
#          Gradient evaluations: 7887
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000128
#          Iterations: 7104
#          Function evaluations: 7567
#          Gradient evaluations: 7555
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 8219
#          Function evaluations: 9282
#          Gradient evaluations: 9270
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 1.670498
#          Iterations: 394
#          Function evaluations: 452
#          Gradient evaluations: 452
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 11885
#          Function evaluations: 13610
#          Gradient evaluations: 13599
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000073
#          Iterations: 12775
#          Function evaluations: 13635
#          Gradient evaluations: 13623
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 8626
#          Function evaluations: 9741
#          Gradient evaluations: 9730
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.425501
#          Iterations: 11373
#          Function evaluations: 12186
#          Gradient evaluations: 12174
#   0%|          | 0/10 [00:00<?, ?it/s]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 6399
#          Function evaluations: 7382
#          Gradient evaluations: 7370
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.235806
#          Iterations: 19672
#          Function evaluations: 20841
#          Gradient evaluations: 20829
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 8537
#          Function evaluations: 9820
#          Gradient evaluations: 9809
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 9585
#          Function evaluations: 10169
#          Gradient evaluations: 10157
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 4236
#          Function evaluations: 4761
#          Gradient evaluations: 4750
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 18237
#          Function evaluations: 19288
#          Gradient evaluations: 19276
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 8004
#          Function evaluations: 9151
#          Gradient evaluations: 9139
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 12472
#          Function evaluations: 13233
#          Gradient evaluations: 13221
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 3196
#          Function evaluations: 3647
#          Gradient evaluations: 3636
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 10378
#          Function evaluations: 11160
#          Gradient evaluations: 11148
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 5259
#          Function evaluations: 5937
#          Gradient evaluations: 5925
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 14860
#          Function evaluations: 15897
#          Gradient evaluations: 15886
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 8035
#          Function evaluations: 9166
#          Gradient evaluations: 9154
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000001
#          Iterations: 8775
#          Function evaluations: 9480
#          Gradient evaluations: 9468
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 9514
#          Function evaluations: 10784
#          Gradient evaluations: 10772
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000005
#          Iterations: 8825
#          Function evaluations: 9529
#          Gradient evaluations: 9517
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 6448
#          Function evaluations: 7319
#          Gradient evaluations: 7307
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 19678
#          Function evaluations: 20829
#          Gradient evaluations: 20819
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 5081
#          Function evaluations: 5710
#          Gradient evaluations: 5698
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000054
#          Iterations: 3801
#          Function evaluations: 4047
#          Gradient evaluations: 4035
#   0%|          | 0/10 [00:00<?, ?it/s]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 8257
#          Function evaluations: 9419
#          Gradient evaluations: 9408
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 18993
#          Function evaluations: 20100
#          Gradient evaluations: 20088
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 11568
#          Function evaluations: 13115
#          Gradient evaluations: 13106
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 17829
#          Function evaluations: 18932
#          Gradient evaluations: 18921
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 7892
#          Function evaluations: 8917
#          Gradient evaluations: 8905
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000004
#          Iterations: 7265
#          Function evaluations: 7751
#          Gradient evaluations: 7739
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 9290
#          Function evaluations: 10522
#          Gradient evaluations: 10511
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000001
#          Iterations: 12338
#          Function evaluations: 12978
#          Gradient evaluations: 12966
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 3596
#          Function evaluations: 4045
#          Gradient evaluations: 4033
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 12226
#          Function evaluations: 13033
#          Gradient evaluations: 13021
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 4174
#          Function evaluations: 4739
#          Gradient evaluations: 4730
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 11478
#          Function evaluations: 12083
#          Gradient evaluations: 12071
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 9797
#          Function evaluations: 11084
#          Gradient evaluations: 11073
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 20261
#          Function evaluations: 21425
#          Gradient evaluations: 21413
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 9779
#          Function evaluations: 11101
#          Gradient evaluations: 11090
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 11339
#          Function evaluations: 12044
#          Gradient evaluations: 12032
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 8947
#          Function evaluations: 10187
#          Gradient evaluations: 10175
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 12115
#          Function evaluations: 12835
#          Gradient evaluations: 12823
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 12755
#          Function evaluations: 14380
#          Gradient evaluations: 14370
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000009
#          Iterations: 8547
#          Function evaluations: 9149
#          Gradient evaluations: 9137

# %%
for width in widths:
    n_params = (1 * width + width) + (width * width + width) + (width * 1 + 1)
    plt.scatter([n_params]*repeats, results_boosted[width], color='C0')
plt.yscale('log')
plt.ylabel("MSE loss")
plt.xscale('log')
plt.xlabel("parameters")
plt.title("Pure BFGS training with error-learning (half and half)")
# Out:
# Text(0.5, 1.0, 'Pure BFGS training with error-learning (half and half)')

# %%
for i, width in enumerate(widths):
    label1 = "normal training" if i == 0 else None
    label2 = "error learning" if i == 0 else None
    n_params = (1 * width + width) + (width * width + width) + (width * 1 + 1)
    plt.scatter([n_params]*repeats, results[width], color='red', alpha=0.3, label=label1, s=80)
    plt.scatter([n_params]*repeats, results_boosted[width], color='C0', label=label2)
plt.yscale('log')
plt.ylabel("MSE loss")
plt.xscale('log')
plt.xlabel("parameters")
plt.legend()

# %%
with torch.no_grad():
    print(mse_loss_fn_torch(f1(x_i) + (1/c1)*f2(x_i), y_i).item())
# Out:
# 2.8700470225002928e-18

# %%
squishedf = nn.Sequential(
    nn.Linear(1, int(width)),
    nn.Tanh(),
    nn.Linear(int(width), int(width)),
    nn.Tanh(),
    nn.Linear(int(width), 1)
).to(device)

# %%
with torch.no_grad():
    for p in squishedf.parameters():
        p.data = torch.zeros(p.shape).to(device)

with torch.no_grad():
    squishedf[0].bias[0:12] = f1[0].bias
    squishedf[0].bias[12:] = f2[0].bias
    
    squishedf[2].bias[0:12] = f1[2].bias
    squishedf[2].bias[12:] = f2[2].bias
    
    squishedf[4].bias[0] = f1[4].bias + (1/c1)*f2[4].bias
#     squishedf[4].bias[0] = f1[4].bias
#     squishedf[4].bias[0] = f2[4].bias

with torch.no_grad():
    squishedf[0].weight[0:12, :] = f1[0].weight
    squishedf[0].weight[12:24, :] = f2[0].weight
    
    squishedf[2].weight[0:12, 0:12] = f1[2].weight
    squishedf[2].weight[12:24, 12:24] = f2[2].weight
    
    squishedf[4].weight[:, 0:12] = f1[4].weight
    squishedf[4].weight[:, 12:24] = (1/c1)*f2[4].weight
#     squishedf[4].weight[:, 12:24] = torch.zeros((1, 12)).to(device)
#     squishedf[4].weight[:, 12:24] = f2[4].weight

# %%
with torch.no_grad():
    print(mse_loss_fn_torch(squishedf(x_i), y_i).item())
# Out:
# 2.870047031317198e-18

# %%
params = []
shapes = []
lengths = []
for param in squishedf.parameters():
    param_np = param.data.detach().clone().cpu().numpy()
    shapes.append(param_np.shape)
    param_np_flat = param_np.flatten()
    lengths.append(len(param_np_flat))
    params.append(param_np_flat)

param_vector = np.concatenate(params)


result = optimize.minimize(loss,
                       param_vector, 
                       args=(lengths, shapes, squishedf, mse_loss_fn_torch, x_i, y_i, device),
                       jac=gradient,
                       method='BFGS',
                       options={
                           'disp': True,
                           'gtol': 1e-40,
                           'maxiter': 25000,
#                                'finite_diff_rel_step': 1e-15
                       },
                    )

l = 0
for j, param in enumerate(squishedf.parameters()):
    param_data = result.x[l:l+lengths[j]]
    l += lengths[j]
    param_data_shaped = param_data.reshape(shapes[j])
    param.data = torch.tensor(param_data_shaped).to(device)
# Out:
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 8307
#          Function evaluations: 9218
#          Gradient evaluations: 9206

# %%
with torch.no_grad():
    print(mse_loss_fn_torch(squishedf(x_i), y_i).item())
# Out:
# 3.000981923205073e-11

# %% [markdown]
# #### hahaha okay so training the merged network fails miserably. maybe some quirk of BFGS's initial steps? Maybe BFGS doesn't work well if you started it from the minimum? But this would contradict some earlier experiments.... weird.

# %%
widths = [28, 30, 32, 34, 36, 38, 40]
repeats = 10

results_boosted2 = defaultdict(list)

for width in tqdm(widths):
    for _ in tqdm(range(repeats), leave=False):

        f1 = nn.Sequential(
            nn.Linear(1, int(width/2)),
            nn.Tanh(),
            nn.Linear(int(width/2), int(width/2)),
            nn.Tanh(),
            nn.Linear(int(width/2), 1)
        ).to(device)

        params1 = []
        shapes1 = []
        lengths1 = []
        for param in f1.parameters():
            param_np = param.data.detach().clone().cpu().numpy()
            shapes1.append(param_np.shape)
            param_np_flat = param_np.flatten()
            lengths1.append(len(param_np_flat))
            params1.append(param_np_flat)

        param_vector1 = np.concatenate(params1)

        result = optimize.minimize(loss,
                               param_vector1, 
                               args=(lengths1, shapes1, f1, mse_loss_fn_torch, x_i, y_i, device),
                               jac=gradient,
                               method='BFGS',
                               options={
                                   'disp': True,
                                   'gtol': 1e-40,
                                   'maxiter': 25000,
        #                                'finite_diff_rel_step': 1e-15
                               },
                            )

        l = 0
        for j, param in enumerate(f1.parameters()):
            param_data = result.x[l:l+lengths1[j]]
            l += lengths1[j]
            param_data_shaped = param_data.reshape(shapes1[j])
            param.data = torch.tensor(param_data_shaped).to(device)

#         l = mse_loss_fn_torch(f1(x_i), y_i).item()
#         print(l)
#         f1.zero_grad()


        with torch.no_grad():
            c1 = 1 / torch.mean(torch.abs(y_i - f1(x_i))).item()
            yd1_i = c1 * (y_i - f1(x_i))


        f2 = nn.Sequential(
            nn.Linear(1, int(width/2)),
            nn.Tanh(),
            nn.Linear(int(width/2), int(width/2)),
            nn.Tanh(),
            nn.Linear(int(width/2), 1)
        ).to(device)

        params2 = []
        shapes2 = []
        lengths2 = []
        for param in f2.parameters():
            param_np = param.data.detach().clone().cpu().numpy()
            shapes2.append(param_np.shape)
            param_np_flat = param_np.flatten()
            lengths2.append(len(param_np_flat))
            params2.append(param_np_flat)

        param_vector2 = np.concatenate(params1)


        result = optimize.minimize(loss,
                               param_vector2, 
                               args=(lengths2, shapes2, f2, mse_loss_fn_torch, x_i, yd1_i, device),
                               jac=gradient,
                               method='BFGS',
                               options={
                                   'disp': True,
                                   'gtol': 1e-40,
                                   'maxiter': 25000,
        #                                'finite_diff_rel_step': 1e-15
                               },
                            )

        l = 0
        for j, param in enumerate(f2.parameters()):
            param_data = result.x[l:l+lengths2[j]]
            l += lengths2[j]
            param_data_shaped = param_data.reshape(shapes2[j])
            param.data = torch.tensor(param_data_shaped).to(device)

#         l = mse_loss_fn_torch(f2(x_i), yd1_i).item()
#         print(l)
#         f2.zero_grad()

        with torch.no_grad():
            results_boosted2[width].append(mse_loss_fn_torch(f1(x_i) + (1/c1)*f2(x_i), y_i).item())
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 7144
#          Function evaluations: 8095
#          Gradient evaluations: 8083
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 1.366678
#          Iterations: 75
#          Function evaluations: 116
#          Gradient evaluations: 104
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 12968
#          Function evaluations: 14731
#          Gradient evaluations: 14719
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 1.336853
#          Iterations: 313
#          Function evaluations: 346
#          Gradient evaluations: 346
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 8915
#          Function evaluations: 10097
#          Gradient evaluations: 10086
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 1.435321
#          Iterations: 238
#          Function evaluations: 278
#          Gradient evaluations: 278
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 6680
#          Function evaluations: 7586
#          Gradient evaluations: 7581
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 1.724823
#          Iterations: 62
#          Function evaluations: 66
#          Gradient evaluations: 66
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 4913
#          Function evaluations: 5608
#          Gradient evaluations: 5597
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 10990
#          Function evaluations: 11725
#          Gradient evaluations: 11713
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 12081
#          Function evaluations: 13911
#          Gradient evaluations: 13900
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 19332
#          Function evaluations: 20432
#          Gradient evaluations: 20420
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 7942
#          Function evaluations: 8986
#          Gradient evaluations: 8974
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000000
#          Iterations: 25000
#          Function evaluations: 26234
#          Gradient evaluations: 26234
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 10321
#          Function evaluations: 11803
#          Gradient evaluations: 11790
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 15708
#          Function evaluations: 16681
#          Gradient evaluations: 16669
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 7124
#          Function evaluations: 7856
#          Gradient evaluations: 7844
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000014
#          Iterations: 4124
#          Function evaluations: 4418
#          Gradient evaluations: 4406
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 7876
#          Function evaluations: 8940
#          Gradient evaluations: 8928
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 23721
#          Function evaluations: 25006
#          Gradient evaluations: 24994
#   0%|          | 0/10 [00:00<?, ?it/s]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 7551
#          Function evaluations: 8573
#          Gradient evaluations: 8561
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 12671
#          Function evaluations: 13322
#          Gradient evaluations: 13310
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 7456
#          Function evaluations: 8409
#          Gradient evaluations: 8397
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 23050
#          Function evaluations: 24329
#          Gradient evaluations: 24317
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 10550
#          Function evaluations: 11979
#          Gradient evaluations: 11967
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 12322
#          Function evaluations: 13052
#          Gradient evaluations: 13042
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 11996
#          Function evaluations: 13703
#          Gradient evaluations: 13692
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 14406
#          Function evaluations: 15290
#          Gradient evaluations: 15278
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 5078
#          Function evaluations: 5780
#          Gradient evaluations: 5768
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 1.312366
#          Iterations: 159
#          Function evaluations: 176
#          Gradient evaluations: 176
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 18184
#          Function evaluations: 19343
#          Gradient evaluations: 19333
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 10219
#          Function evaluations: 11521
#          Gradient evaluations: 11509
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 20940
#          Function evaluations: 22036
#          Gradient evaluations: 22025
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 9620
#          Function evaluations: 11022
#          Gradient evaluations: 11010
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 22715
#          Function evaluations: 24147
#          Gradient evaluations: 24136
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 16877
#          Function evaluations: 19214
#          Gradient evaluations: 19203
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 16567
#          Function evaluations: 17605
#          Gradient evaluations: 17593
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 5355
#          Function evaluations: 6063
#          Gradient evaluations: 6051
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 1.519908
#          Iterations: 124
#          Function evaluations: 168
#          Gradient evaluations: 156
#   0%|          | 0/10 [00:00<?, ?it/s]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 7378
#          Function evaluations: 8370
#          Gradient evaluations: 8361
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000000
#          Iterations: 25000
#          Function evaluations: 26194
#          Gradient evaluations: 26194
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 8045
#          Function evaluations: 9139
#          Gradient evaluations: 9129
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000000
#          Iterations: 25000
#          Function evaluations: 26173
#          Gradient evaluations: 26173
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 5813
#          Function evaluations: 6602
#          Gradient evaluations: 6591
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 24325
#          Function evaluations: 25546
#          Gradient evaluations: 25534
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 9816
#          Function evaluations: 10966
#          Gradient evaluations: 10954
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 9327
#          Function evaluations: 9856
#          Gradient evaluations: 9844
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 4325
#          Function evaluations: 4926
#          Gradient evaluations: 4914
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 18978
#          Function evaluations: 20281
#          Gradient evaluations: 20271
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 8121
#          Function evaluations: 9265
#          Gradient evaluations: 9253
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 18233
#          Function evaluations: 19378
#          Gradient evaluations: 19366
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 8444
#          Function evaluations: 9738
#          Gradient evaluations: 9727
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 15193
#          Function evaluations: 16233
#          Gradient evaluations: 16222
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 3908
#          Function evaluations: 4364
#          Gradient evaluations: 4358
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 7788
#          Function evaluations: 8364
#          Gradient evaluations: 8352
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 17259
#          Function evaluations: 19593
#          Gradient evaluations: 19582
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000000
#          Iterations: 25000
#          Function evaluations: 26461
#          Gradient evaluations: 26461
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 12470
#          Function evaluations: 14232
#          Gradient evaluations: 14221
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000000
#          Iterations: 25000
#          Function evaluations: 26366
#          Gradient evaluations: 26366
#   0%|          | 0/10 [00:00<?, ?it/s]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 10585
#          Function evaluations: 12068
#          Gradient evaluations: 12056
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 11231
#          Function evaluations: 11942
#          Gradient evaluations: 11930
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 5852
#          Function evaluations: 6644
#          Gradient evaluations: 6632
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 13520
#          Function evaluations: 14230
#          Gradient evaluations: 14218
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 8386
#          Function evaluations: 9654
#          Gradient evaluations: 9642
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 16640
#          Function evaluations: 17603
#          Gradient evaluations: 17591
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 7568
#          Function evaluations: 8731
#          Gradient evaluations: 8720
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 15679
#          Function evaluations: 16756
#          Gradient evaluations: 16745
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 7584
#          Function evaluations: 8817
#          Gradient evaluations: 8805
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000000
#          Iterations: 25000
#          Function evaluations: 26462
#          Gradient evaluations: 26462
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 3357
#          Function evaluations: 3899
#          Gradient evaluations: 3887
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 19490
#          Function evaluations: 20654
#          Gradient evaluations: 20643
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 9674
#          Function evaluations: 11160
#          Gradient evaluations: 11148
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 16884
#          Function evaluations: 17839
#          Gradient evaluations: 17827
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 4563
#          Function evaluations: 5158
#          Gradient evaluations: 5147
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 20534
#          Function evaluations: 21602
#          Gradient evaluations: 21591
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 5596
#          Function evaluations: 6350
#          Gradient evaluations: 6338
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 11371
#          Function evaluations: 12352
#          Gradient evaluations: 12342
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 11465
#          Function evaluations: 13094
#          Gradient evaluations: 13083
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 18043
#          Function evaluations: 19118
#          Gradient evaluations: 19106
#   0%|          | 0/10 [00:00<?, ?it/s]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 8598
#          Function evaluations: 9870
#          Gradient evaluations: 9858
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 10150
#          Function evaluations: 10711
#          Gradient evaluations: 10699
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 8691
#          Function evaluations: 9859
#          Gradient evaluations: 9847
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 16369
#          Function evaluations: 17287
#          Gradient evaluations: 17275
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 5559
#          Function evaluations: 6290
#          Gradient evaluations: 6278
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 20082
#          Function evaluations: 21129
#          Gradient evaluations: 21117
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 5517
#          Function evaluations: 6206
#          Gradient evaluations: 6194
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 15119
#          Function evaluations: 15930
#          Gradient evaluations: 15918
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 5911
#          Function evaluations: 6747
#          Gradient evaluations: 6736
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 17996
#          Function evaluations: 18842
#          Gradient evaluations: 18830
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 9299
#          Function evaluations: 10548
#          Gradient evaluations: 10536
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 15738
#          Function evaluations: 16650
#          Gradient evaluations: 16638
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 15353
#          Function evaluations: 17498
#          Gradient evaluations: 17486
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 20507
#          Function evaluations: 21741
#          Gradient evaluations: 21730
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 6189
#          Function evaluations: 7086
#          Gradient evaluations: 7074
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000003
#          Iterations: 17395
#          Function evaluations: 18082
#          Gradient evaluations: 18070
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 9666
#          Function evaluations: 10974
#          Gradient evaluations: 10962
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000002
#          Iterations: 11382
#          Function evaluations: 12063
#          Gradient evaluations: 12051
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 10096
#          Function evaluations: 11546
#          Gradient evaluations: 11534
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000000
#          Iterations: 25000
#          Function evaluations: 26506
#          Gradient evaluations: 26506
#   0%|          | 0/10 [00:00<?, ?it/s]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 7943
#          Function evaluations: 8960
#          Gradient evaluations: 8948
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 18959
#          Function evaluations: 20154
#          Gradient evaluations: 20143
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 8500
#          Function evaluations: 9692
#          Gradient evaluations: 9681
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 1.442500
#          Iterations: 97
#          Function evaluations: 105
#          Gradient evaluations: 105
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 7006
#          Function evaluations: 7938
#          Gradient evaluations: 7926
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 10857
#          Function evaluations: 11529
#          Gradient evaluations: 11518
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 5209
#          Function evaluations: 5871
#          Gradient evaluations: 5860
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 12072
#          Function evaluations: 12839
#          Gradient evaluations: 12828
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 7765
#          Function evaluations: 8842
#          Gradient evaluations: 8830
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 14511
#          Function evaluations: 15514
#          Gradient evaluations: 15502
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 8618
#          Function evaluations: 9775
#          Gradient evaluations: 9763
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 13157
#          Function evaluations: 14098
#          Gradient evaluations: 14086
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 8372
#          Function evaluations: 9494
#          Gradient evaluations: 9485
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 17547
#          Function evaluations: 18521
#          Gradient evaluations: 18509
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 8495
#          Function evaluations: 9688
#          Gradient evaluations: 9676
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 16048
#          Function evaluations: 17013
#          Gradient evaluations: 17001
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 5539
#          Function evaluations: 6300
#          Gradient evaluations: 6288
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 16937
#          Function evaluations: 17817
#          Gradient evaluations: 17805
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 3812
#          Function evaluations: 4262
#          Gradient evaluations: 4251
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 24978
#          Function evaluations: 26613
#          Gradient evaluations: 26601
#   0%|          | 0/10 [00:00<?, ?it/s]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 4795
#          Function evaluations: 5454
#          Gradient evaluations: 5442
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 15617
#          Function evaluations: 16478
#          Gradient evaluations: 16468
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 9318
#          Function evaluations: 10768
#          Gradient evaluations: 10756
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000000
#          Iterations: 25000
#          Function evaluations: 26113
#          Gradient evaluations: 26113
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 15638
#          Function evaluations: 17979
#          Gradient evaluations: 17967
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 15909
#          Function evaluations: 16816
#          Gradient evaluations: 16804
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 4829
#          Function evaluations: 5534
#          Gradient evaluations: 5522
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 22740
#          Function evaluations: 23872
#          Gradient evaluations: 23860
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 6643
#          Function evaluations: 7488
#          Gradient evaluations: 7477
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000000
#          Iterations: 25000
#          Function evaluations: 26198
#          Gradient evaluations: 26198
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 3447
#          Function evaluations: 3880
#          Gradient evaluations: 3868
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 20390
#          Function evaluations: 21443
#          Gradient evaluations: 21433
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 6352
#          Function evaluations: 7223
#          Gradient evaluations: 7212
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000000
#          Iterations: 25000
#          Function evaluations: 26180
#          Gradient evaluations: 26180
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 4323
#          Function evaluations: 4861
#          Gradient evaluations: 4849
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 21795
#          Function evaluations: 22985
#          Gradient evaluations: 22973
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 11448
#          Function evaluations: 12950
#          Gradient evaluations: 12938
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 21498
#          Function evaluations: 22776
#          Gradient evaluations: 22765
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 4962
#          Function evaluations: 5607
#          Gradient evaluations: 5595
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 18277
#          Function evaluations: 19224
#          Gradient evaluations: 19213

# %%
for i, width in enumerate([4, 6, 8, 10, 12, 16, 18, 20, 22, 24]):
    label1 = "normal training" if i == 0 else None
    n_params = (1 * width + width) + (width * width + width) + (width * 1 + 1)
    plt.scatter([n_params]*repeats, results[width], color='red', alpha=0.3, label=label1, s=80)
    
for i, width in enumerate([4, 6, 8, 10, 12, 16, 18, 20, 22, 24]):
    label2 = "error learning" if i == 0 else None
    n_params = (1 * width + width) + (width * width + width) + (width * 1 + 1)
    plt.scatter([n_params]*repeats, results_boosted[width], color='C0', label=label2)
    
for width in [28, 30, 32, 34, 36, 38, 40]:
    n_params = (1 * width + width) + (width * width + width) + (width * 1 + 1)
    plt.scatter([n_params]*repeats, results_boosted2[width], color='C0', label=label2)
    

plt.yscale('log')
plt.ylabel("MSE loss")
plt.xscale('log')
plt.xlabel("parameters")
plt.legend()

# %%
min(results[24])
# Out:
# 1.8557098513439183e-14

# %%
min(results_boosted[24])
# Out:
# 3.176704943400539e-21

# %%
with torch.no_grad():
    print(mse_loss_fn_torch(f1(x_i) + (1/c1)*f2(x_i), y_i).item())
# Out:
# 1.692283728020906e-21

# %%
x_i_test = np.random.uniform(low=-1, high=1, size=(50000, 1))
y_i_test = a + b*np.power(x_i_test, 1) + c*np.power(x_i_test, 2) + d*np.power(x_i_test, 3) + e*np.power(x_i_test, 4) + f*np.power(x_i_test, 5)

x_i_test = torch.from_numpy(x_i_test).to(device)
y_i_test = torch.from_numpy(y_i_test).to(device)

# %%
with torch.no_grad():
    print(mse_loss_fn_torch(f1(x_i_test) + (1/c1)*f2(x_i_test), y_i_test).item())
# Out:
# 1.6886510117116225e-21

# %%
f2[4].weight / c1
# Out:
# tensor([[-1.3587e-05,  6.8387e-06,  1.5565e-05,  4.3974e-06,  2.2605e-05,
#          -5.1332e-06,  9.2804e-06,  7.0399e-06,  7.6754e-06,  1.8890e-05,
#          -1.1254e-05, -1.7990e-05,  2.6265e-07, -1.3004e-05,  5.7309e-06,
#           1.7531e-05, -8.8974e-06,  1.7174e-06,  2.1130e-06,  8.1288e-07]],
#        device='cuda:0', grad_fn=<DivBackward0>)

# %%
f1[4].weight
# Out:
# Parameter containing:
# tensor([[ 1.0728, -0.9456, -0.7889,  0.5661, -0.2194, -0.1688,  0.2728,  0.0031,
#           2.5520,  0.1008, -1.1897,  1.4671, -1.4482,  1.1754, -2.4007,  0.1994,
#           1.0346, -0.8455, -0.4240,  0.3245]], device='cuda:0',
#        requires_grad=True)

# %% [markdown]
# ### Do a 1/3 2/3rds split

# %%
widths = [6, 9, 12, 15, 18, 21, 24, 27]
repeats = 10

results_boosted3 = defaultdict(list)

for width in tqdm(widths):
    for _ in tqdm(range(repeats), leave=False):

        f1 = nn.Sequential(
            nn.Linear(1, int(width/3)),
            nn.Tanh(),
            nn.Linear(int(width/3), int(width/3)),
            nn.Tanh(),
            nn.Linear(int(width/3), 1)
        ).to(device)

        params1 = []
        shapes1 = []
        lengths1 = []
        for param in f1.parameters():
            param_np = param.data.detach().clone().cpu().numpy()
            shapes1.append(param_np.shape)
            param_np_flat = param_np.flatten()
            lengths1.append(len(param_np_flat))
            params1.append(param_np_flat)

        param_vector1 = np.concatenate(params1)

        result = optimize.minimize(loss,
                               param_vector1, 
                               args=(lengths1, shapes1, f1, mse_loss_fn_torch, x_i, y_i, device),
                               jac=gradient,
                               method='BFGS',
                               options={
                                   'disp': True,
                                   'gtol': 1e-40,
                                   'maxiter': 25000,
        #                                'finite_diff_rel_step': 1e-15
                               },
                            )

        l = 0
        for j, param in enumerate(f1.parameters()):
            param_data = result.x[l:l+lengths1[j]]
            l += lengths1[j]
            param_data_shaped = param_data.reshape(shapes1[j])
            param.data = torch.tensor(param_data_shaped).to(device)

#         l = mse_loss_fn_torch(f1(x_i), y_i).item()
#         print(l)
#         f1.zero_grad()


        with torch.no_grad():
            c1 = 1 / torch.mean(torch.abs(y_i - f1(x_i))).item()
            yd1_i = c1 * (y_i - f1(x_i))


        f2 = nn.Sequential(
            nn.Linear(1, int(2*width/3)),
            nn.Tanh(),
            nn.Linear(int(2*width/3), int(2*width/3)),
            nn.Tanh(),
            nn.Linear(int(2*width/3), 1)
        ).to(device)

        params2 = []
        shapes2 = []
        lengths2 = []
        for param in f2.parameters():
            param_np = param.data.detach().clone().cpu().numpy()
            shapes2.append(param_np.shape)
            param_np_flat = param_np.flatten()
            lengths2.append(len(param_np_flat))
            params2.append(param_np_flat)

        param_vector2 = np.concatenate(params2)


        result = optimize.minimize(loss,
                               param_vector2, 
                               args=(lengths2, shapes2, f2, mse_loss_fn_torch, x_i, yd1_i, device),
                               jac=gradient,
                               method='BFGS',
                               options={
                                   'disp': True,
                                   'gtol': 1e-40,
                                   'maxiter': 25000,
        #                                'finite_diff_rel_step': 1e-15
                               },
                            )

        l = 0
        for j, param in enumerate(f2.parameters()):
            param_data = result.x[l:l+lengths2[j]]
            l += lengths2[j]
            param_data_shaped = param_data.reshape(shapes2[j])
            param.data = torch.tensor(param_data_shaped).to(device)

#         l = mse_loss_fn_torch(f2(x_i), yd1_i).item()
#         print(l)
#         f2.zero_grad()

        with torch.no_grad():
            results_boosted3[width].append(mse_loss_fn_torch(f1(x_i) + (1/c1)*f2(x_i), y_i).item())
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 2000
#          Function evaluations: 2314
#          Gradient evaluations: 2302
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000012
#          Iterations: 2325
#          Function evaluations: 2592
#          Gradient evaluations: 2580
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.003563
#          Iterations: 1013
#          Function evaluations: 1243
#          Gradient evaluations: 1231
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 3688
#          Function evaluations: 4214
#          Gradient evaluations: 4202
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000335
#          Iterations: 645
#          Function evaluations: 802
#          Gradient evaluations: 790
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 2434
#          Function evaluations: 2762
#          Gradient evaluations: 2750
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000001
#          Iterations: 2707
#          Function evaluations: 3149
#          Gradient evaluations: 3137
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.085218
#          Iterations: 2453
#          Function evaluations: 2763
#          Gradient evaluations: 2751
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000001
#          Iterations: 3958
#          Function evaluations: 4683
#          Gradient evaluations: 4671
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.003202
#          Iterations: 9116
#          Function evaluations: 10132
#          Gradient evaluations: 10120
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000338
#          Iterations: 2726
#          Function evaluations: 3241
#          Gradient evaluations: 3229
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.003951
#          Iterations: 588
#          Function evaluations: 714
#          Gradient evaluations: 702
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000132
#          Iterations: 1967
#          Function evaluations: 2337
#          Gradient evaluations: 2325
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000002
#          Iterations: 1813
#          Function evaluations: 2034
#          Gradient evaluations: 2022
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000001
#          Iterations: 2459
#          Function evaluations: 2948
#          Gradient evaluations: 2936
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000076
#          Iterations: 3437
#          Function evaluations: 3837
#          Gradient evaluations: 3825
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000142
#          Iterations: 1999
#          Function evaluations: 2406
#          Gradient evaluations: 2394
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000066
#          Iterations: 2079
#          Function evaluations: 2332
#          Gradient evaluations: 2320
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 1544
#          Function evaluations: 1805
#          Gradient evaluations: 1793
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.157527
#          Iterations: 1113
#          Function evaluations: 1266
#          Gradient evaluations: 1254
#   0%|          | 0/10 [00:00<?, ?it/s]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 8268
#          Function evaluations: 9471
#          Gradient evaluations: 9460
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.453965
#          Iterations: 3809
#          Function evaluations: 4079
#          Gradient evaluations: 4067
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000005
#          Iterations: 8565
#          Function evaluations: 10251
#          Gradient evaluations: 10239
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 2738
#          Function evaluations: 3007
#          Gradient evaluations: 2995
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 10732
#          Function evaluations: 12341
#          Gradient evaluations: 12333
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000001
#          Iterations: 4980
#          Function evaluations: 5367
#          Gradient evaluations: 5355
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 4018
#          Function evaluations: 4613
#          Gradient evaluations: 4601
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000003
#          Iterations: 3935
#          Function evaluations: 4331
#          Gradient evaluations: 4319
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 3029
#          Function evaluations: 3453
#          Gradient evaluations: 3441
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.378718
#          Iterations: 2458
#          Function evaluations: 2778
#          Gradient evaluations: 2766
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000001
#          Iterations: 2206
#          Function evaluations: 2581
#          Gradient evaluations: 2569
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 9241
#          Function evaluations: 10087
#          Gradient evaluations: 10075
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 6601
#          Function evaluations: 7705
#          Gradient evaluations: 7693
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.002038
#          Iterations: 4623
#          Function evaluations: 5096
#          Gradient evaluations: 5084
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 6020
#          Function evaluations: 6807
#          Gradient evaluations: 6795
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.133171
#          Iterations: 2521
#          Function evaluations: 2747
#          Gradient evaluations: 2735
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 6612
#          Function evaluations: 7536
#          Gradient evaluations: 7524
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.091216
#          Iterations: 3658
#          Function evaluations: 4025
#          Gradient evaluations: 4013
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 3214
#          Function evaluations: 3691
#          Gradient evaluations: 3679
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000001
#          Iterations: 2174
#          Function evaluations: 2417
#          Gradient evaluations: 2405
#   0%|          | 0/10 [00:00<?, ?it/s]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 10979
#          Function evaluations: 12536
#          Gradient evaluations: 12524
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000023
#          Iterations: 11264
#          Function evaluations: 12146
#          Gradient evaluations: 12134
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 6054
#          Function evaluations: 6819
#          Gradient evaluations: 6807
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.002468
#          Iterations: 7209
#          Function evaluations: 7838
#          Gradient evaluations: 7826
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 15021
#          Function evaluations: 17146
#          Gradient evaluations: 17135
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 6504
#          Function evaluations: 7048
#          Gradient evaluations: 7036
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 4481
#          Function evaluations: 5155
#          Gradient evaluations: 5143
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 12865
#          Function evaluations: 13892
#          Gradient evaluations: 13880
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 5565
#          Function evaluations: 6293
#          Gradient evaluations: 6281
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000019
#          Iterations: 2982
#          Function evaluations: 3314
#          Gradient evaluations: 3302
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 4901
#          Function evaluations: 5497
#          Gradient evaluations: 5485
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000011
#          Iterations: 3031
#          Function evaluations: 3301
#          Gradient evaluations: 3289
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 6743
#          Function evaluations: 7711
#          Gradient evaluations: 7699
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.012863
#          Iterations: 7335
#          Function evaluations: 7920
#          Gradient evaluations: 7908
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 3547
#          Function evaluations: 4130
#          Gradient evaluations: 4118
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.292057
#          Iterations: 4202
#          Function evaluations: 4503
#          Gradient evaluations: 4491
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 5913
#          Function evaluations: 6693
#          Gradient evaluations: 6682
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000185
#          Iterations: 9623
#          Function evaluations: 10345
#          Gradient evaluations: 10333
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 5697
#          Function evaluations: 6526
#          Gradient evaluations: 6514
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 6463
#          Function evaluations: 7072
#          Gradient evaluations: 7060
#   0%|          | 0/10 [00:00<?, ?it/s]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 15925
#          Function evaluations: 18110
#          Gradient evaluations: 18099
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000010
#          Iterations: 9407
#          Function evaluations: 10081
#          Gradient evaluations: 10069
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 10483
#          Function evaluations: 12110
#          Gradient evaluations: 12098
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000012
#          Iterations: 6707
#          Function evaluations: 7198
#          Gradient evaluations: 7186
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 4345
#          Function evaluations: 4905
#          Gradient evaluations: 4893
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 11358
#          Function evaluations: 12146
#          Gradient evaluations: 12134
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 3568
#          Function evaluations: 4047
#          Gradient evaluations: 4041
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 10301
#          Function evaluations: 11115
#          Gradient evaluations: 11103
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 5626
#          Function evaluations: 6493
#          Gradient evaluations: 6483
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 22355
#          Function evaluations: 24037
#          Gradient evaluations: 24023
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 5075
#          Function evaluations: 5801
#          Gradient evaluations: 5791
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 8438
#          Function evaluations: 9035
#          Gradient evaluations: 9023
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 11891
#          Function evaluations: 13667
#          Gradient evaluations: 13655
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000007
#          Iterations: 7398
#          Function evaluations: 7931
#          Gradient evaluations: 7919
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 12757
#          Function evaluations: 14866
#          Gradient evaluations: 14855
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 21229
#          Function evaluations: 22724
#          Gradient evaluations: 22712
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 7907
#          Function evaluations: 8987
#          Gradient evaluations: 8979
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000001
#          Iterations: 10445
#          Function evaluations: 11177
#          Gradient evaluations: 11165
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 12101
#          Function evaluations: 13885
#          Gradient evaluations: 13873
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 16016
#          Function evaluations: 16982
#          Gradient evaluations: 16970
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 17048
#          Function evaluations: 19467
#          Gradient evaluations: 19455
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 11538
#          Function evaluations: 12403
#          Gradient evaluations: 12391
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 3756
#          Function evaluations: 4307
#          Gradient evaluations: 4295
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000001
#          Iterations: 17902
#          Function evaluations: 18903
#          Gradient evaluations: 18891
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 14534
#          Function evaluations: 16472
#          Gradient evaluations: 16460
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 12421
#          Function evaluations: 13251
#          Gradient evaluations: 13239
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 6536
#          Function evaluations: 7404
#          Gradient evaluations: 7392
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 7560
#          Function evaluations: 7975
#          Gradient evaluations: 7964
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 5304
#          Function evaluations: 5990
#          Gradient evaluations: 5978
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.194102
#          Iterations: 14668
#          Function evaluations: 15680
#          Gradient evaluations: 15669
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 5630
#          Function evaluations: 6484
#          Gradient evaluations: 6472
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 10643
#          Function evaluations: 11546
#          Gradient evaluations: 11534
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 4624
#          Function evaluations: 5207
#          Gradient evaluations: 5197
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000000
#          Iterations: 25000
#          Function evaluations: 26486
#          Gradient evaluations: 26486
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 6382
#          Function evaluations: 7346
#          Gradient evaluations: 7334
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 10909
#          Function evaluations: 11704
#          Gradient evaluations: 11693
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 12572
#          Function evaluations: 14373
#          Gradient evaluations: 14361
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 24967
#          Function evaluations: 26586
#          Gradient evaluations: 26574
#   0%|          | 0/10 [00:00<?, ?it/s]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 7340
#          Function evaluations: 8471
#          Gradient evaluations: 8459
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 19875
#          Function evaluations: 21146
#          Gradient evaluations: 21138
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 13632
#          Function evaluations: 15510
#          Gradient evaluations: 15499
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 20710
#          Function evaluations: 21962
#          Gradient evaluations: 21950
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 14274
#          Function evaluations: 16297
#          Gradient evaluations: 16286
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 15470
#          Function evaluations: 16230
#          Gradient evaluations: 16219
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 5867
#          Function evaluations: 6685
#          Gradient evaluations: 6675
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000005
#          Iterations: 6932
#          Function evaluations: 7334
#          Gradient evaluations: 7322
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 7930
#          Function evaluations: 9038
#          Gradient evaluations: 9026
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 15528
#          Function evaluations: 16495
#          Gradient evaluations: 16483
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 6808
#          Function evaluations: 7704
#          Gradient evaluations: 7693
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 10102
#          Function evaluations: 10699
#          Gradient evaluations: 10687
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 9688
#          Function evaluations: 11010
#          Gradient evaluations: 10998
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 15846
#          Function evaluations: 16830
#          Gradient evaluations: 16818
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 6013
#          Function evaluations: 6825
#          Gradient evaluations: 6813
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 10100
#          Function evaluations: 10857
#          Gradient evaluations: 10845
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 6638
#          Function evaluations: 7629
#          Gradient evaluations: 7617
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 5238
#          Function evaluations: 5603
#          Gradient evaluations: 5591
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 8069
#          Function evaluations: 9239
#          Gradient evaluations: 9228
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 1.394288
#          Iterations: 96
#          Function evaluations: 99
#          Gradient evaluations: 99
#   0%|          | 0/10 [00:00<?, ?it/s]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 6072
#          Function evaluations: 6899
#          Gradient evaluations: 6887
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 12544
#          Function evaluations: 13435
#          Gradient evaluations: 13423
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 3794
#          Function evaluations: 4265
#          Gradient evaluations: 4253
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 18929
#          Function evaluations: 20041
#          Gradient evaluations: 20030
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 7004
#          Function evaluations: 7945
#          Gradient evaluations: 7933
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 18146
#          Function evaluations: 19081
#          Gradient evaluations: 19069
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 10408
#          Function evaluations: 11847
#          Gradient evaluations: 11835
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 9574
#          Function evaluations: 10109
#          Gradient evaluations: 10097
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 5845
#          Function evaluations: 6574
#          Gradient evaluations: 6564
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000000
#          Iterations: 25000
#          Function evaluations: 26444
#          Gradient evaluations: 26444
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 5630
#          Function evaluations: 6417
#          Gradient evaluations: 6406
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000000
#          Iterations: 25000
#          Function evaluations: 26340
#          Gradient evaluations: 26340
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 12277
#          Function evaluations: 14264
#          Gradient evaluations: 14252
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 12228
#          Function evaluations: 13101
#          Gradient evaluations: 13089
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 7641
#          Function evaluations: 8640
#          Gradient evaluations: 8628
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 18689
#          Function evaluations: 19837
#          Gradient evaluations: 19825
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 7614
#          Function evaluations: 8661
#          Gradient evaluations: 8649
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 21972
#          Function evaluations: 23343
#          Gradient evaluations: 23332
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 5369
#          Function evaluations: 6053
#          Gradient evaluations: 6042
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 24972
#          Function evaluations: 26280
#          Gradient evaluations: 26268
#   0%|          | 0/10 [00:00<?, ?it/s]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 7130
#          Function evaluations: 8006
#          Gradient evaluations: 7994
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 12230
#          Function evaluations: 12876
#          Gradient evaluations: 12864
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 5340
#          Function evaluations: 6073
#          Gradient evaluations: 6061
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 15769
#          Function evaluations: 16549
#          Gradient evaluations: 16538
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 6502
#          Function evaluations: 7382
#          Gradient evaluations: 7371
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 18071
#          Function evaluations: 19126
#          Gradient evaluations: 19114
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 3136
#          Function evaluations: 3552
#          Gradient evaluations: 3540
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 17543
#          Function evaluations: 18593
#          Gradient evaluations: 18582
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 9306
#          Function evaluations: 10613
#          Gradient evaluations: 10601
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 19567
#          Function evaluations: 20465
#          Gradient evaluations: 20453
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 6129
#          Function evaluations: 7009
#          Gradient evaluations: 6997
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 19212
#          Function evaluations: 20396
#          Gradient evaluations: 20385
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 6739
#          Function evaluations: 7709
#          Gradient evaluations: 7698
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000000
#          Iterations: 25000
#          Function evaluations: 26560
#          Gradient evaluations: 26560
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 6943
#          Function evaluations: 7746
#          Gradient evaluations: 7734
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 14972
#          Function evaluations: 15829
#          Gradient evaluations: 15817
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 10976
#          Function evaluations: 12522
#          Gradient evaluations: 12510
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 13292
#          Function evaluations: 14120
#          Gradient evaluations: 14108
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 6089
#          Function evaluations: 6965
#          Gradient evaluations: 6953
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000000
#          Iterations: 9882
#          Function evaluations: 10604
#          Gradient evaluations: 10592

# %% [markdown]
# ### Wow, I just noticed a very subtle bug. I should redo my earlier experiments. I had set param_vector2 = np.concatenate(params1) before, instead of params2.

# %%
for i, width in enumerate([4, 6, 8, 10, 12, 16, 18, 20, 22, 24]):
    label1 = "normal training" if i == 0 else None
    n_params = (1 * width + width) + (width * width + width) + (width * 1 + 1)
    plt.scatter([n_params]*repeats, results[width], color='red', alpha=0.3, label=label1, s=80)
    
for i, width in enumerate([4, 6, 8, 10, 12, 16, 18, 20, 22, 24]):
    label2 = "1/2 1/2 residual split" if i == 0 else None
    n_params = (1 * width + width) + (width * width + width) + (width * 1 + 1)
    plt.scatter([n_params]*repeats, results_boosted[width], color='C0', label=label2)
    
for i, width in enumerate([28, 30, 32, 34, 36, 38, 40]):
    n_params = (1 * width + width) + (width * width + width) + (width * 1 + 1)
    plt.scatter([n_params]*repeats, results_boosted2[width], color='C0')

for i, width in enumerate([6, 9, 12, 15, 18, 21, 24, 27]):
    label3 = "1/3 2/3 residual split" if i == 0 else None
    n_params = (1 * width + width) + (width * width + width) + (width * 1 + 1)
    plt.scatter([n_params]*repeats, results_boosted3[width], color='green', label=label3, alpha=0.3)
    
plt.yscale('log')
plt.ylabel("MSE loss")
plt.xscale('log')
plt.xlabel("parameters")
plt.legend()
